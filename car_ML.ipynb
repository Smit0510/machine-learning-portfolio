# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
s=StandardScaler()
r=LinearRegression()

# %%
df=pd.read_csv('quikr_car.csv')
df.shape

# %%
df.head()

# %%
df.info()

# %%
df['name'].astype(str)
df['name']=df['name'].str.split().str[:3].str.join(' ')

# %%
df['year'].unique()

# %%
df=df[df['year'].str.isnumeric()]

# %%
df['year'].unique()

# %%
df['year']=df['year'].astype(int)

# %%
df.info()

# %%
df['Price'].unique()

# %%
df=df[df['Price']!='Ask For Price']

# %%
df['Price']=df['Price'].str.replace(',','').astype(int)

# %%
df.info()

# %%
df['kms_driven'].unique()

# %%
df=df[df['kms_driven']!='Petrol']

# %%
df['kms_driven']=df['kms_driven'].str.split(' ').str.get(0).str.replace(',','').astype(int)

# %%
df.info()

# %%
cat_col=df.select_dtypes(include='object').columns
cat_col

# %%
df[cat_col].isnull().sum()

# %%
imputer_mode=SimpleImputer(strategy='most_frequent')
imputer_mode

# %%
imputer_mode.fit(df[cat_col])

# %%
imputer_mode.statistics_

# %%
df[cat_col]=imputer_mode.transform(df[cat_col])

# %%
df[cat_col].isnull().sum()

# %%
encoder = LabelEncoder()
df['nameEncod'] = encoder.fit_transform(df['name'])
df['companyEncod'] = encoder.fit_transform(df['company'])
df['fuel_typeEncod'] = encoder.fit_transform(df['fuel_type'])
df

# %%
df.isnull().sum()

# %%
df.head()

# %%
plt.scatter(df['name'],df['Price'])
plt.xlabel("name")
plt.ylabel("Price")

# %%
x=df[['nameEncod']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("name")
plt.ylabel("Price")

# %%
plt.scatter(df['company'],df['Price'])
plt.xlabel("company")
plt.ylabel("Price")

# %%
x=df[['companyEncod']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("company")
plt.ylabel("Price")

# %%
plt.scatter(df['year'],df['Price'])
plt.xlabel("year")
plt.ylabel("Price")

# %%
x=df[['year']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("year")
plt.ylabel("Price")

# %%
plt.scatter(df['kms_driven'],df['Price'])
plt.xlabel("kms_driven")
plt.ylabel("Price")

# %%
x=df[['kms_driven']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("kms_driven")
plt.ylabel("Price")

# %%
plt.scatter(df['fuel_type'],df['Price'])
plt.xlabel("fuel_type")
plt.ylabel("Price")

# %%
x=df[['fuel_typeEncod']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("fuel_type")
plt.ylabel("Price")

# %%
# Polynomial features 
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree=3)

# %%
x_poly = poly_reg.fit_transform(x)
poly_reg.fit(x_poly, y)

# %%
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, r.predict(x), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('kms driven')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
r.predict(np.array(1).reshape(1, -1))

# %%
lin_reg_2.predict(poly_reg.fit_transform(np.array(1).reshape(1, -1)))
