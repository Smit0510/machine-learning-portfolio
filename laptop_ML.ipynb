# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
s=StandardScaler()
r=LinearRegression()

# %%
df=pd.read_csv('laptop_data.csv')
df.head()

# %%
df.info()

# %%
df['Cpu'].astype(str)
df['Cpu']=df['Cpu'].str.split().str[:3].str.join(' ')
df.head()

# %%
df['Ram'] = df['Ram'].str.replace('GB', '').astype(int)
df.info()

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype(float)

# %%
df.info()

# %%
df['ScreenResolution'].unique()

# %%
df['IPS Panel']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS Panel' in x else 0)

# %%
df['Retina Display']=df['ScreenResolution'].apply(lambda x: 1 if 'Retina Display' in x else 0)

# %%
df['Full HD']=df['ScreenResolution'].apply(lambda x: 1 if 'Full HD' in x else 0)

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df['Quad HD+']=df['ScreenResolution'].apply(lambda x: 1 if 'Quad HD+' in x else 0)

# %%
df['4K Ultra HD']=df['ScreenResolution'].apply(lambda x: 1 if '4K Ultra HD' in x else 0)

# %%
df.head()

# %%
df['Memory'].unique()

# %%
df['SSD']=df['Memory'].apply(lambda x: 1 if 'SSD' in x else 0)

# %%
df['Flash Storage']=df['Memory'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

# %%
df['HDD']=df['Memory'].apply(lambda x: 1 if 'HDD' in x else 0)

# %%
df['Hybrid']=df['Memory'].apply(lambda x: 1 if 'Hybrid' in x else 0)

# %%
df.head()

# %%
df['Memory']=df['Memory'].str.split(' ').str.get(0)

# %%
df.head()

# %%
df['ScreenResolution']=df['ScreenResolution'].str.split(' ').str.get(-1)

# %%
df.head()

# %%
cat_col=df.select_dtypes(include='object').columns
cat_col

# %%
encoder = LabelEncoder()
df['CompanyEncode'] = encoder.fit_transform(df['Company'])
df['TypeNameEncode'] = encoder.fit_transform(df['TypeName'])
df['ScreenResolutionEncode'] = encoder.fit_transform(df['ScreenResolution'])
df['CpuEncode'] = encoder.fit_transform(df['Cpu'])
df['MemoryEncode'] = encoder.fit_transform(df['Memory'])
df['GpuEncode'] = encoder.fit_transform(df['Gpu'])
df['OpSysEncode'] = encoder.fit_transform(df['OpSys'])

df

# %%
plt.scatter(df['Company'],df['Price'])
plt.xlabel("Company")
plt.ylabel("Price")

# %%
x=df[['CompanyEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("company")
plt.ylabel("Price")

# %%
x=df[['TypeNameEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("typename")
plt.ylabel("Price")

# %%
x=df[['Inches']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("inchs")
plt.ylabel("Price")

# %%
x=df[['ScreenResolutionEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("ScreenResolution")
plt.ylabel("Price")

# %%
x=df[['CpuEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("CPU")
plt.ylabel("Price")

# %%
x=df[['Ram']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
x_test

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("RAM")
plt.ylabel("Price")

# %%
x=df[['MemoryEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("Memory")
plt.ylabel("Price")

# %%
x=df[['GpuEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("GPU")
plt.ylabel("Price")

# %%
x=df[['OpSysEncode']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("OPSystem")
plt.ylabel("Price")

# %%
x=df[['Weight']]
y=df['Price']

# %%
x.shape,y.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
x_train=s.fit_transform(x_train)

# %%
x_test=s.transform(x_test)

# %%
plt.scatter(x_train,y_train)

# %%
r.fit(x_train,y_train)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,r.predict(x_train), color='green')
plt.xlabel("Weight")
plt.ylabel("Price")

# %%
df=df.drop(columns=cat_col)

# %%
x = df.iloc[:, 1:2].values
y = df.iloc[:, 2].values

# %%
x_train = s.fit_transform(x_train)
x_test = s.transform(x_test)

# %%
r.fit(x, y)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree=4)

# %%
x_poly = poly_reg.fit_transform(x)
poly_reg.fit(x_poly, y)

# %%
r_2 = LinearRegression()
r_2.fit(x_poly, y)

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, r.predict(x), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, r_2.predict(poly_reg.fit_transform(x)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
X_grid = np.arange(min(x), max(x), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(x, y, color = 'red')
plt.plot(X_grid, r_2.predict(poly_reg.fit_transform(X_grid)), color ='blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
r.predict(np.array(15).reshape(1,-1))

# %%
r_2.predict(poly_reg.fit_transform(np.array(15).reshape(1,-1)))
